# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# bring in data
clean_data_num = pd.read_csv('/content/drive/MyDrive/UNC /Graduate School/SPRING 26/DATA 780/780 Final Project /clean_20_years_numeric.csv')

# index
clean_data_index = clean_data_num.sort_values(['Country Name', 'Series'])
clean_data_index.set_index(['Country Name', 'Series'], inplace=True)

clean_data_index.head()
# Out:
#                                      2002         2003         2004  \
# Country Name Series
# Albania      GDP_const        2297.108535  2428.689347  2567.297637
#              GDP_growth          4.942623     5.728106     5.707123
#              ed_attain_fem            NaN          NaN          NaN
#              ed_attain_male           NaN          NaN          NaN
#              ed_attain_total          NaN          NaN          NaN
#
#                                      2005         2006         2007  \
# Country Name Series
# Albania      GDP_const        2712.869838  2894.360326  3105.879676
#              GDP_growth          5.670250     6.689981     7.307983
#              ed_attain_fem            NaN          NaN    34.464465
#              ed_attain_male           NaN          NaN    45.635701
#              ed_attain_total          NaN          NaN    39.913693
#
#                                      2008         2009         2010  \
# Country Name Series
# ...
